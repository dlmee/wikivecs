# %%
import json
import matplotlib.pyplot as plt
from collections import Counter

# Function to read JSON file and return data
def read_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Function to bin the counts into specified ranges
def bin_counts(data):
    bins = {
        'Over 500,000': 0,
        '300,000 to 500,000': 0,
        '100,000 to 300,000': 0,
        '50,000 to 100,000': 0,
        '10,000 to 50,000': 0,
        '5,000 to 10,000': 0,
        '1,000 to 5,000': 0,
        '500 to 1,000': 0,
        '100 to 500': 0,
        '50 to 100': 0,
        '10 to 50': 0,
        '1 to 10': 0,
    }
    
    for count in data.values():
        if count > 500000:
            bins['Over 500,000'] += 1
        elif count > 300000:
            bins['300,000 to 500,000'] += 1
        elif count > 100000:
            bins['100,000 to 300,000'] += 1
        elif count > 50000:
            bins['50,000 to 100,000'] += 1
        elif count > 10000:
            bins['10,000 to 50,000'] += 1
        elif count > 5000:
            bins['5,000 to 10,000'] += 1
        elif count > 1000:
            bins['1,000 to 5,000'] += 1
        elif count > 500:
            bins['500 to 1,000'] += 1
        elif count > 100:
            bins['100 to 500'] += 1
        elif count > 50:
            bins['50 to 100'] += 1
        elif count > 10:
            bins['10 to 50'] += 1
        else:
            bins['1 to 10'] += 1
    
    return bins

# Function to plot the counts
def plot_counts(bins):
    labels = list(bins.keys())
    counts = list(bins.values())
    
    plt.figure(figsize=(14, 8))
    plt.bar(labels, counts, color='skyblue')
    plt.xlabel('Count Ranges')
    plt.ylabel('Number of Verbs')
    plt.title('Binned Counts of Verb Occurrences in Wikipedia')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Main function
def main(file_path):
    data = read_json(file_path)
    bins = bin_counts(data)
    plot_counts(bins)

# Example usage
if __name__ == "__main__":
    file_path = 'wiki_knowledge/verb_counts_0.json'  # Replace with your JSON file path
    main(file_path)

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Function to read JSON file and return data
def read_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Function to dynamically build bins based on a Zipfian distribution
def build_zipfian_bins(data, num_bins=20):
    # Extract and sort values in descending order
    values = sorted(data.values(), reverse=True)
    n = len(values)

    # Calculate the cutoffs based on a Zipfian-like distribution
    bin_ratios = np.logspace(0, np.log10(n), num_bins + 1, base=10).astype(int)
    bin_edges = sorted(set(bin_ratios))  # Ensure unique and sorted
    bin_edges = [edge for edge in bin_edges if edge < n]  # Remove any edges beyond n

    # Generate bin labels with actual value ranges
    bin_labels = []
    for i in range(len(bin_edges)):
        if i == 0:
            bin_labels.append(f"{values[0]}-{values[bin_edges[i]-1]}")
        else:
            bin_labels.append(f"{values[bin_edges[i-1]]}-{values[bin_edges[i]-1]}")

    # Add an additional bin for the last edge to the end
    bin_labels.append(f"{values[bin_edges[-1]]}-{values[-1]}")

    # Count the occurrences of values falling within each bin
    bins = {label: 0 for label in bin_labels}
    bin_idx = 0
    for i in range(n):
        if bin_idx < len(bin_edges) and i >= bin_edges[bin_idx]:
            bin_idx += 1
        if bin_idx < len(bin_labels):
            bins[bin_labels[bin_idx]] += 1

    return bins

# Function to plot the counts
def plot_counts(bins):
    labels = list(bins.keys())
    counts = list(bins.values())
    
    plt.figure(figsize=(14, 8))
    plt.bar(labels, counts, color='skyblue')
    plt.xlabel('Value Ranges')
    plt.ylabel('Number of Verbs')
    plt.title('Binned Counts of Verb Occurrences Based on Zipfian Distribution')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

    # Print the counts
    for label, count in bins.items():
        print(f"{label}: {count}")

# Main function
def main(file_path, num_bins=20):
    data = read_json(file_path)
    bins = build_zipfian_bins(data, num_bins)
    plot_counts(bins)

# Example usage
if __name__ == "__main__":
    file_path = 'wiki_knowledge/link_counts.json'  # Replace with your JSON file path
    main(file_path, num_bins=20)  # Adjust num_bins for more or fewer bins

# %%
import matplotlib.pyplot as plt

# List of strings representing the bins and counts
bins_counts = [
    "10796855-10796855: 1",
    "5777540-5777540: 1",
    "3679427-2504580: 2",
    "2234089-1674826: 4",
    "1612306-1242745: 6",
    "1242107-940140: 10",
    "928497-779129: 17",
    "778630-566576: 28",
    "564589-360152: 49",
    "358906-225738: 84",
    "225639-133407: 141",
    "133345-74552: 241",
    "74545-36100: 410",
    "36082-15853: 696",
    "15847-5803: 1184",
    "5800-1768: 2014",
    "1764-388: 3424",
    "388-51: 5823",
    "51-6: 9902",
    "6-1: 16838"
]

# Extract the leftmost number in each row
leftmost_numbers = [int(bin_count.split('-')[0]) for bin_count in bins_counts]

# Plot the leftmost numbers
plt.figure(figsize=(14, 8))
plt.plot(leftmost_numbers, marker='o', linestyle='-')
plt.xlabel('Bin Index')
plt.ylabel('Leftmost Number')
plt.title('Leftmost Number in Each Bin')
plt.yscale('log')  # Log scale to better visualize the Zipfian distribution
plt.grid(True)
plt.show()

# Print the leftmost numbers for reference
print("Leftmost numbers:", leftmost_numbers)

# %%
import matplotlib.pyplot as plt

# List of strings representing the bins and counts
bins_counts = [
    "10796855-10796855: 1",
    "5777540-5777540: 1",
    "3679427-2504580: 2",
    "2234089-1674826: 4",
    "1612306-1242745: 6",
    "1242107-940140: 10",
    "928497-779129: 17",
    "778630-566576: 28",
    "564589-360152: 49",
    "358906-225738: 84",
    "225639-133407: 141",
    "133345-74552: 241",
    "74545-36100: 410",
    "36082-15853: 696",
    "15847-5803: 1184",
    "5800-1768: 2014",
    "1764-388: 3424",
    "388-51: 5823",
    "51-6: 9902",
    "6-1: 16838"
]

# Extract the leftmost number in each row
leftmost_numbers = [int(bin_count.split('-')[0]) for bin_count in bins_counts]

# Plot the leftmost numbers
plt.figure(figsize=(14, 8))
plt.plot(leftmost_numbers, marker='o', linestyle='-')
plt.xlabel('Bin Index')
plt.ylabel('Leftmost Number')
plt.title('Leftmost Number in Each Bin')
plt.yscale('log')  # Log scale to better visualize the Zipfian distribution
plt.grid(True)
plt.gca().invert_yaxis()  # Invert the y-axis to show the distribution in the "upside-down" format
plt.show()

# Print the leftmost numbers for reference
print("Leftmost numbers:", leftmost_numbers)

# %%
import sqlite3
import json

def create_table(cursor):
    """Create the table in the SQLite database."""
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS records (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            key TEXT,
            value TEXT
        )
    ''')

def insert_record(cursor, key, value):
    """Insert a record into the SQLite database."""
    cursor.execute('''
        INSERT INTO records (key, value)
        VALUES (?, ?)
    ''', (key, value))

def retrieve_record(cursor, key):
    """Retrieve a record from the SQLite database by key."""
    cursor.execute('''
        SELECT value FROM records WHERE key=?
    ''', (key,))
    row = cursor.fetchone()
    return row[0] if row else None

def load_db(db_filename):
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    return cursor

def test_database(cursor, target):
    """Test the SQLite database by creating a table, inserting records, and retrieving them."""
    value_str = retrieve_record(cursor, target)
    value = json.loads(value_str)
    print(f"Key: {target}, Value: {value}")

# Example usage
db_filename = 'wikilinksdata.db'
cursor = load_db(db_filename)

# %%
test_database(cursor, "Ronald Reagan")

# %%
import sqlite3
import pandas as pd

# Function to query the level1alt table and return a pandas DataFrame
def query_level1_table(db_filename):
    """Query the level1alt table and return its contents as a pandas DataFrame."""
    conn = sqlite3.connect(db_filename)
    
    # Use pandas to read the level1alt table into a DataFrame
    #df = pd.read_sql_query('SELECT * FROM level1final LIMIT 100', conn)
    df = pd.read_sql_query('SELECT * FROM level1unified LIMIT 500', conn)
    # Close the connection
    conn.close()
    
    return df

# Function to get the total number of rows in the level1alt table
def get_row_count(db_filename):
    """Get the total number of rows in the level1 table."""
    conn = sqlite3.connect(db_filename)
    
    # Execute a query to count the rows
    cursor = conn.cursor()
    cursor.execute('SELECT COUNT(*) FROM level1unified')
    row_count = cursor.fetchone()[0]
    
    # Close the connection
    conn.close()
    
    return row_count

# Example usage
db_filename = 'database/wikilinks_main.db'
df_level1 = query_level1_table(db_filename)
# Get and display the total number of rows
total_rows = get_row_count(db_filename)
print(f"Total number of rows in the table: {total_rows}")
# Display the head of the DataFrame
df_level1.head(50)
# Out:
# Total number of rows in the table: 22946567
#     id                                               keys  \
# 0    1  [3075584, 10290947, 9859588, 8950408, 2739723,...
# 1    2  [10040322, 4850180, 5428238, 6678032, 4922386,...
# 2    3  [603905, 1582211, 603910, 8626322, 648212, 100...
# 3    4  [4646912, 9859588, 1500677, 4196888, 7182368, ...
# 4    5  [5169409, 9464577, 4261635, 10314372, 2801415,...
# 5    6  [3209224, 2739723, 8046606, 6678032, 1329173, ...
# 6    7  [4920713, 2709130, 10704397, 7544980, 7068571,...
# 7    8  [9471876, 10174855, 3746056, 3562634, 4198027,...
# 8    9  [3808131, 5083284, 11119124, 14491, 6488363, 2...
# 9   10  [9859588, 7193611, 8496653, 9738253, 9494035, ...
# 10  11  [10864259, 11578371, 6804741, 2657542, 1147431...
# 11  12  [5762692, 7399781, 10302854, 2801415, 2823784,...
# 12  13  [1553411, 9859588, 2724871, 1329173, 7660054, ...
# 13  14  [6571137, 7610625, 9464577, 2901764, 2824837, ...
# 14  15  [3471392, 2137250, 9948194, 8461668, 11093378,...
# 15  16  [4055137, 6245987, 1964164, 4389639, 4055067, ...
# 16  17  [9872389, 4920713, 2709130, 11119124, 14491, 2...
# 17  18  [829440, 1553411, 7193611, 8496653, 1329173, 8...
# 18  19  [5019008, 7404673, 9464577, 10866946, 4820868,...
# 19  20  [1264643, 2724871, 8950408, 3947788, 11667086,...
# 20  21  [1553411, 11204107, 8496653, 3209232, 9494035,...
# 21  22  [9208321, 4845702, 2724871, 593416, 9568140, 8...
# 22  23  [10867456, 7607938, 3808131, 8701186, 914565, ...
# 23  24  [7210497, 8662027, 3882005, 10740758, 11320345...
# 24  25  [6564867, 7211494, 1900487, 7455256, 9976428, ...
# 25  26  [3209224, 2709130, 7435404, 10040724, 14491, 8...
# 26  27  [1500677, 10907910, 10174855, 8950408, 8496653...
# 27  28                                        ["UNKNOWN"]
# 28  29  [8917253, 2724871, 3077639, 8950408, 10066183,...
# 29  30  [10960899, 1549317, 698887, 2724871, 4568074, ...
# 30  31  [829440, 2739723, 755725, 2701326, 1408527, 66...
# 31  32  [1852419, 2739723, 1329173, 3882005, 1572381, ...
# 32  33  [5169409, 9341316, 10314372, 2801415, 2739723,...
# 33  34  [2784260, 10088838, 9650568, 2709130, 1536271,...
# 34  35  [2701570, 10864259, 4391558, 2108169, 6898059,...
# 35  36  [8789126, 3311882, 8179090, 7929751, 606487, 8...
# 36  37  [5376, 10957057, 9342721, 6244227, 9471876, 48...
# 37  38  [6864526, 8757647, 8251927, 14491, 4652959, 33...
# 38  39  [4190977, 5914376, 8950408, 4198027, 8428043, ...
# 39  40  [3866112, 8496653, 6678032, 1329173, 3383840, ...
# 40  41  [3242501, 1497607, 3209232, 10829841, 1497618,...
# 41  42  [2380614, 3342918, 641179, 9738253, 8963153, 9...
# 42  43  [9324801, 6244227, 2784260, 9471876, 2682252, ...
# 43  44  [3295748, 1571335, 10761224, 9738253, 10704397...
# 44  45  [6914947, 7077897, 10832905, 11444745, 1028610...
# 45  46  [8178689, 11578371, 3334150, 4568074, 3054093,...
# 46  47  [1237763, 813841, 4347285, 3704985, 4828570, 1...
# 47  48  [9464577, 9859588, 9872389, 10088838, 3822343,...
# 48  49  [10867456, 8950408, 7500554, 3947788, 2140558,...
# 49  50  [8581376, 5169409, 2553476, 2801415, 1842956, ...
#
#                                                  name  \
# 0             Draft:Gysbert Reitz Hofmeyr (1871-1942)
# 1       List of solved missing person cases: pre-2000
# 2                           Bakugan: Armored Alliance
# 3                                History of Palestine
# 4   List of acts of the Parliament of Great Britai...
# 5                      Foreign relations of Australia
# 6            List of The Beverly Hillbillies episodes
# 7                      List of In Our Time programmes
# 8   List of cases of the January 6 United States C...
# 9                         2023 in American television
# 10                             Characters of Casualty
# 11                 Criminal procedure in South Africa
# 12                              List of Nova episodes
# 13            Bible-Presbyterian churches (Singapore)
# 14    List of The Walking Dead (TV series) characters
# 15       Anne de Montmorency, 1st Duke of Montmorency
# 16                       List of Saint Seiya episodes
# 17                        2018 in American television
# 18                                   Kashmir conflict
# 19                         1st Maine Cavalry Regiment
# 20                        2021 in American television
# 21             List of historic properties in Phoenix
# 22  Timeline of the Israeli–Palestinian conflict i...
# 23           List of Australian multilateral treaties
# 24  Listed buildings in Leeds (City and Hunslet Wa...
# 25                    Passaic station (Erie Railroad)
# 26                                    Tesla Autopilot
# 27              Template:Imagemap Germany district AA
# 28  United States House Select Committee on the Ja...
# 29  Timeline of women's legal rights in the United...
# 30                             Indigenous Australians
# 31                         History of the Philippines
# 32  List of ordinances and acts of the Parliament ...
# 33                         BBC Television Shakespeare
# 34                                    Valentino Rossi
# 35                                    Nothing Records
# 36     University of Scranton buildings and landmarks
# 37                      List of Danger Force episodes
# 38                             2018 in paleomammalogy
# 39  List of accidents and incidents involving mili...
# 40                            Authoritarian socialism
# 41       List of The Biggest Loser Australia episodes
# 42          Features of the Marvel Cinematic Universe
# 43                         List of Jackanory episodes
# 44                           Football Far North Coast
# 45                             Fortnite Battle Royale
# 46                                 Andreas Hillgruber
# 47                                       Erwin Rommel
# 48                                     Yom Kippur War
# 49  List of English translations from medieval sou...
#
#                                                 names
# 0   ["Historical", "Coloured", "References", "Albe...
# 1   ["JewishEncyclopedia.com", "Islamic", "Babysit...
# 2   ["7a", "Secrets", "Bakugan", "3b", "Premieres"...
# 3   ["Islamic", "Neo-Babylonian", "3700", "Rural",...
# 4   ["Shore", "Amsinck", "Merchants", "Terms", "Ri...
# 5   ["Islamic", "Nuku'alofa", "RAMSI", "Right", "T...
# 6   ["Topless", "References", "Muscles", "Hungry",...
# 7   ["Historical", "Patristic", "Islamic", "Archit...
# 8   ["Iowan", "Sweet", "Leader", "Shalvey", "Insur...
# 9   ["Right", "Blacklist", "Rural", "WNBA", "Premi...
# 10  ["Falklands", "Spy", "DEC", "F1", "Britney", "...
# 11  ["Telegraphic", "Courts", "References", "Types...
# 12  ["Islamic", "Right", "BFI", "Supersonic", "Con...
# 13  ["Historical", "M.Div", "Translations", "Under...
# 14  ["Lintz", "Stalker", "Wolves", "Previews", "CD...
# 15  ["Le", "Bourgogne", "Governors", "M\u00e9dicis...
# 16  ["Hungry", "Right", "Sweet", "Naze", "Needles"...
# 17  ["Plains", "Right", "Parents", "Blacklist", "S...
# 18  ["Islamic", "References", "Right", "Challenges...
# 19  ["Historical", "Anthropological", "Plains", "C...
# 20  ["Hispanics", "Right", "Parents", "Previews", ...
# 21  ["7h", "Historical", "Botanical", "Municipal",...
# 22  ["Timeline of the Israeli\u2013Palestinian con...
# 23  ["Right", "Amendments", "Biological", "Statute...
# 24  ["Sep", "Statues", "Archives", "Crispin", "Boa...
# 25  ["Historical", "Merchants", "References", "Rum...
# 26  ["Confident", "References", "Terms", "Right", ...
# 27          ["Template:Imagemap Germany district AA"]
# 28  ["United States House Select Committee on the ...
# 29  ["Policies", "Labor", "Right", "Savings", "Con...
# 30  ["Terms", "Plains", "Travelling", "Rural", "Ge...
# 31  ["Anthropological", "Islamic", "Indo-Chinese",...
# 32  ["Colleges", "Herrings", "Merchants", "Persons...
# 33  ["Shore", "Simonides", "Sweet", "Summers", "Cl...
# 34  ["Poor", "Jerez", "F1", "FIA", "Taxes", "UK", ...
# 35  ["Floodgates", "Rumors", "Parents", "Midwest",...
# 36  ["Historical", "Technologies", "Architectural"...
# 37  ["List of Danger Force episodes", "References"...
# 38  ["2066", "Boyko", "Microscopic", "Zurita", "An...
# 39  ["BT-13", "Bakers", "Fg", "Swords", "P-51", "S...
# 40  ["Policies", "Labor", "Councils", "Maurya", "T...
# 41  ["Sandwiches", "4k", "Champions", "Mediterrane...
# 42  ["Wundagore", "References", "MCU", "Ants", "Nt...
# 43  ["Thursdays", "Baling", "Rajah", "Tweedledum",...
# 44  ["Historical", "Goonellabah", "Quarter-final",...
# 45  ["Rifts", "Skywalker", "Parents", "Fight", "Yo...
# 46  ["Historical", "Annelise", "German-Jewish", "S...
# 47  ["Historical", "Fatherland", "Taking", "Spy", ...
# 48  ["Historical", "Islamic", "Troops", "Tanks", "...
# 49  ["Historical", "Translations", "\u00d3enach", ...

# %%
import sqlite3

def create_index(db_filename, table_name, column_name):
    """Create an index on the specified column of the specified table."""
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    
    index_name = f'idx_{column_name}'
    cursor.execute(f'CREATE INDEX IF NOT EXISTS {index_name} ON {table_name}({column_name})')
    
    conn.commit()
    conn.close()
    print(f"Index on {column_name} created successfully.")

# Example usage
db_filename = 'wikilinksdata.db'
table_name = 'records'
column_name = 'emb_idx'
create_index(db_filename, table_name, column_name)
# Out:
# Index on emb_idx created successfully.

# %%
import sqlite3
import pandas as pd

# Function to query the level1alt table and return a pandas DataFrame
def query_level1_table(db_filename):
    """Query the level1alt table and return its contents as a pandas DataFrame."""
    conn = sqlite3.connect(db_filename)
    
    # Use pandas to read the level1alt table into a DataFrame
    #df = pd.read_sql_query('SELECT * FROM level1final LIMIT 100', conn)
    df = pd.read_sql_query('SELECT * FROM embeddings LIMIT 5', conn)
    # Close the connection
    conn.close()
    
    return df

# Function to get the total number of rows in the level1alt table
def get_row_count(db_filename):
    """Get the total number of rows in the level1 table."""
    conn = sqlite3.connect(db_filename)
    
    # Execute a query to count the rows
    cursor = conn.cursor()
    cursor.execute('SELECT COUNT(*) FROM embeddings WHERE LENGTH("values") > 5')
    row_count = cursor.fetchone()[0]
    
    # Close the connection
    conn.close()
    
    return row_count

# Example usage
db_filename = 'database/final_embedding.db'
df_level1 = query_level1_table(db_filename)
# Get and display the total number of rows
total_rows = get_row_count(db_filename)
print(f"Total number of rows in the table: {total_rows}")
# Display the head of the DataFrame
df_level1.head(50)
# Out:
# Total number of rows in the table: 12983465
#    id  emb_idx                                             values
# 0   1  UNKNOWN  [[0, 0.02531645569620253], [1, 0.0238095238095...
# 1   2  2881033  [[0, 0.43037974683544306], [1, 0.5119047619047...
# 2   3  1094758  [[0, 0.6329113924050633], [1, 0.67857142857142...
# 3   4  UNKNOWN                                                 []
# 4   5   303091  [[0, 0.4177215189873419], [1, 0.28571428571428...

# %%
import sqlite3

def delete_all_from_table(db_filename, table_name):
    """Delete all contents from the specified table."""
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    
    # Execute the delete statement
    cursor.execute(f'DELETE FROM {table_name}')
    
    # Commit the changes and close the connection
    conn.commit()
    conn.close()
    print(f"All contents from table {table_name} have been deleted.")

# Example usage
db_filename = 'wikilinksdata.db'
table_name = 'level1'
delete_all_from_table(db_filename, table_name)
# Out:
# All contents from table level1 have been deleted.

# %%
import sqlite3

def reset_level1_table(db_filename):
    """Reset the level1 table so that it starts indexing from 1 again."""
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    
    # Drop the existing level1 table if it exists
    cursor.execute('DROP TABLE IF EXISTS embeddings')
    
    # Recreate the level1 tabl
    conn.commit()
    conn.close()
    print("The level1 table has been reset and will start indexing from 1.")

# Example usage
db_filename = 'embeddings.db'
reset_level1_table(db_filename)

# %%
import sqlite3

def count_rows_in_table(db_filename, table_name):
    """Count the number of rows in the specified table."""
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    
    cursor.execute(f'SELECT * FROM {table_name}')
    count = cursor.fetchall()
    
    conn.close()
    
    return count

# Example usage
db_filename = 'database/wikilinksdata_0.db'
table_name = 'embeddings'
row_count = count_rows_in_table(db_filename, table_name)
print(row_count[:20])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[57], line 18
#      16 db_filename = 'database/wikilinksdata_0.db'
#      17 table_name = 'embeddings'
# ---> 18 row_count = count_rows_in_table(db_filename, table_name)
#      19 print(row_count[:20])
#
# Cell In[57], line 8, in count_rows_in_table(db_filename, table_name)
#       5 conn = sqlite3.connect(db_filename)
#       6 cursor = conn.cursor()
# ----> 8 cursor.execute(f'SELECT * FROM {table_name}')
#       9 count = cursor.fetchall()
#      11 conn.close()
#
# OperationalError: no such table: embeddings

# %%
import sqlite3
import pandas as pd
import json

# Function to query the level1 table and return a pandas DataFrame
def query_level1_table(db_filename):
    """Query the level1 table and return its contents as a pandas DataFrame."""
    conn = sqlite3.connect(db_filename)
    
    # Use pandas to read the level1 table into a DataFrame
    df = pd.read_sql_query('SELECT * FROM level1', conn)
    
    # Close the connection
    conn.close()
    
    return df

# Function to count the total number of keys (links) in the level1 table
def count_total_keys(df, column_name='keys'):
    """Count the total number of keys (links) across all rows in the specified column."""
    total_keys = 0
    
    for index, row in df.iterrows():
        keys = json.loads(row[column_name])
        total_keys += len(keys)
    
    return total_keys

# Example usage
db_filename = 'wikilinksdata.db'
df_level1 = query_level1_table(db_filename)

# Count the total number of keys (links) in the 'keys' column
total_keys = count_total_keys(df_level1, 'keys')

# Display the total number of keys
print(f"Total number of keys in the table: {total_keys}")
# Out:
# Total number of keys in the table: 8008908

# %%
import sqlite3

def list_tables(db_filename):
    """List all tables in the SQLite database."""
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()

    # Query to get the list of all tables
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    conn.close()
    return [table[0] for table in tables]

def main():
    db_filename = 'embeddings.db'  # Replace with your database filename
    tables = list_tables(db_filename)

    print(f"Tables in {db_filename}:")
    for table in tables:
        print(table)

main()
# Out:
# Tables in embeddings.db:
# embeddings
# sqlite_sequence

# %%
import sqlite3
import pandas as pd

# Function to query the level1alt table and return a pandas DataFrame
def query_level1_table(db_filename):
    """Query the level1alt table and return its contents as a pandas DataFrame."""
    conn = sqlite3.connect(db_filename)
    
    # Use pandas to read the level1alt table into a DataFrame
    #df = pd.read_sql_query('SELECT * FROM level1final LIMIT 100', conn)
    df = pd.read_sql_query('SELECT * FROM Entities LIMIT 50', conn)
    # Close the connection
    conn.close()
    
    return df

# Function to get the total number of rows in the level1alt table
def get_row_count(db_filename):
    """Get the total number of rows in the level1 table."""
    conn = sqlite3.connect(db_filename)
    
    # Execute a query to count the rows
    cursor = conn.cursor()
    cursor.execute('SELECT COUNT(*) FROM Entities')
    row_count = cursor.fetchone()[0]
    
    # Close the connection
    conn.close()
    
    return row_count

# Example usage
db_filename = 'ukwacentity.db'
df_level1 = query_level1_table(db_filename)
# Get and display the total number of rows
total_rows = get_row_count(db_filename)
print(f"Total number of rows in the table: {total_rows}")
# Display the head of the DataFrame
df_level1.head(500)
# Out:
# Total number of rows in the table: 519315
#                                              sentence  \
# 0   If you feel that would like to make a donation...
# 1   Someone else you should contact is your local ...
# 2   That is  it cannot play songs from Apple s onl...
# 3                        Try the Logitech ChillStream
# 4   In Listening Post iPod transmitters to be lega...
# 5   One important point to note is that once aware...
# 6   1592  Hague Roll 1672 Alexander Duncan of Seas...
# 7   Motto  Deo Juvante Vinco 1809 Alexander Duncan...
# 8   Motto  Suffer 1876 MorisonDuncan of Naughton Q...
# 9   Motto Beneath  Secundis dubiisque rectus 1897 ...
# 10  Motto  Periisem ni 1904 William McDougall Dunc...
# 11  Crest  A couped arm naked proper grasping a ga...
# 12  Crest  A cubit arm naked proper grasping a gal...
# 13                                Impaled with Bourne
# 14  Crest  A dexter hand appaum Or proper charged ...
# 15                           Motto  Fear nane but God
# 16  2005 Pearl Rose Duncan  Australia Per chevron ...
# 17                             was born in Lancashire
# 18  He teaches French and Spanish  as well some La...
# 19  Treatment  Only one visit to the clinic Creams...
# 20  A detailed list of clubs and their facilities ...
# 21  If you are part of a club and would like your ...
# 22  Case Study  Isle of Man Government Achieving B...
# 23  Early 2005 saw the achievement of this vision ...
# 24  The provisions governing amendments to the mem...
# 25  In the former type of case we should apply pri...
# 26  To get there  from the city of Swansea drive w...
# 27  This is the area where you have an excellent c...
# 28          This website was created by Michael Clark
# 29  Mike has nothing to do with The Royal Star  Ga...
# 30      That site can be found at wwwstarandgarterorg
# 31  Site History Administration To contact Mike  N...
# 32  The launch follows several years work by the S...
# 33  The inaugural AGM and CPD training seminar was...
# 34  This changing face is primarily about collabor...
# 35  The keynote speakers were Mike Callan  Sports ...
# 36  The AGM commenced with a welcoming address by ...
# 37  On conclusion of the official business Chair h...
# 38  Mike s paper discussed Higher Education Involv...
# 39  However where this has been impossible or impr...
# 40                      PDF  Portable Document Format
# 41                     PDF files are created by Adobe
# 42                         DOC  Microsoft Word Format
# 43  DOC files are created by the popular Microsoft...
# 44                        XLS  Microsoft Excel Format
# 45  XLS files are created by the Microsoft spreads...
# 46  The backend of the site runs on Coldfusion Ser...
# 47  The site was written using Macromedia Dreamwea...
# 48  It was dominated by the FreezeFry cycles of Cr...
# 49  One region of the Neoproterozoic world which i...
#
#                                              entities  \
# 0   ["IsItFair couk Christine Melsom Willow Cottag...
# 1   ["Philip Rees Director TEL", "FAX", "wwwresult...
# 2   ["Apple", "iTunes Store", "Internet", "Tacoma ...
# 3                            ["Logitech ChillStream"]
# 4   ["Listening Post", "Addict 3D", "MP3", "Decemb...
# 5   ["Duncan", "Robertson Struan", "Gordon Stewart...
# 6   ["Hague Roll", "Alexander Duncan", "Seaside", ...
# 7   ["Deo Juvante Vinco", "Alexander Duncan", "Par...
# 8   ["MorisonDuncan", "Naughton", "Gules", "Argent...
# 9              ["Motto Beneath", "Secundis", "Lieut"]
# 10  ["Periisem ni", "William McDougall Duncan", "S...
# 11                        ["Azure", "Saltire Argent"]
# 12                        ["Azure", "Saltire Argent"]
# 13                                         ["Bourne"]
# 14                                          ["Gules"]
# 15                                            ["God"]
# 16  ["Pearl Rose Duncan", "Australia", "Gules", "V...
# 17                                     ["Lancashire"]
# 18                            ["Latin", "Department"]
# 19                                         ["Clinic"]
# 20                          ["Sports Club Directory"]
# 21  ["Sports Club Directory", "Sport Leisure", "Ap...
# 22  ["Case Study", "Isle", "Man", "Achieving BS779...
# 23                                 ["BS7799", "LRQA"]
# 24                                            ["Act"]
# 25  ["OG", "Trustee Indemnity Insurance", "Trustees"]
# 26                             ["Swansea", "Mumbles"]
# 27                            ["August", "September"]
# 28                                  ["Michael Clark"]
# 29  ["Mike", "Royal Star", "Garter Home", "Disable...
# 30                            ["wwwstarandgarterorg"]
# 31  ["Site", "Administration", "Mike", "NOT", "Sta...
# 32  ["South Wales", "West", "England Development G...
# 33  ["AGM", "CPD", "Taunton Deane Leisure", "Life ...
# 34                                     ["South West"]
# 35  ["Mike Callan", "Development Manager Universit...
# 36  ["AGM", "Neil Farmer", "Alan King", "South Wes...
# 37  ["Mike Callan", "Sports Development Manager Un...
# 38  ["Mike", "Higher Education Involvement", "Netw...
# 39                                        ["DOC XLS"]
# 40                ["PDF", "Portable Document Format"]
# 41                                   ["PDF", "Adobe"]
# 42                          ["Microsoft Word Format"]
# 43                              ["Microsoft", "Word"]
# 44                         ["Microsoft Excel Format"]
# 45                      ["XLS", "Microsoft", "Excel"]
# 46             ["Coldfusion Server MX", "Macromedia"]
# 47                      ["Macromedia Dreamweaver MX"]
# 48         ["Cryogenian", "Ma Snowball Earth", "Fig"]
# 49  ["Oil", "North Gondwana Margin", "South Americ...
#
#                                                tagged
# 0   If you feel that would like to make a donation...
# 1   Someone else you should contact is your local ...
# 2   That is  it cannot play songs from <entity> Ap...
# 3     Try the <entity> Logitech ChillStream </entity>
# 4   In <entity> Listening Post </entity> iPod tran...
# 5   One important point to note is that once aware...
# 6   1592  <entity> Hague Roll </entity> 1672 <enti...
# 7   Motto  <entity> Deo Juvante Vinco </entity> 18...
# 8   Motto  Suffer 1876 <entity> MorisonDuncan </en...
# 9   <entity> Motto Beneath </entity>  <entity> Sec...
# 10  Motto  <entity> Periisem ni </entity> 1904 <en...
# 11  Crest  A couped arm naked proper grasping a ga...
# 12  Crest  A cubit arm naked proper grasping a gal...
# 13             Impaled with <entity> Bourne </entity>
# 14  Crest  A dexter hand appaum Or proper charged ...
# 15        Motto  Fear nane but <entity> God </entity>
# 16  2005 <entity> Pearl Rose Duncan </entity>  <en...
# 17          was born in <entity> Lancashire </entity>
# 18  He teaches French and Spanish  as well some <e...
# 19  Treatment  Only one visit to the clinic Creams...
# 20  A detailed list of clubs and their facilities ...
# 21  If you are part of a club and would like your ...
# 22  <entity> Case Study </entity>  <entity> Isle <...
# 23  Early 2005 saw the achievement of this vision ...
# 24  The provisions governing amendments to the mem...
# 25  In the former type of case we should apply pri...
# 26  To get there  from the city of <entity> Swanse...
# 27  This is the area where you have an excellent c...
# 28  This website was created by <entity> Michael C...
# 29  <entity> Mike </entity> has nothing to do with...
# 30  That site can be found at <entity> wwwstarandg...
# 31  <entity> Site </entity> History <entity> Admin...
# 32  The launch follows several years work by the <...
# 33  The inaugural <entity> AGM </entity> and <enti...
# 34  This changing face is primarily about collabor...
# 35  The keynote speakers were <entity> Mike Callan...
# 36  The <entity> AGM </entity> commenced with a we...
# 37  On conclusion of the official business Chair h...
# 38  <entity> Mike </entity> s paper discussed <ent...
# 39  However where this has been impossible or impr...
# 40  <entity> PDF </entity>  <entity> Portable Docu...
# 41  <entity> PDF </entity> files are created by <e...
# 42      DOC  <entity> Microsoft Word Format </entity>
# 43  DOC files are created by the popular <entity> ...
# 44     XLS  <entity> Microsoft Excel Format </entity>
# 45  <entity> XLS </entity> files are created by th...
# 46  The backend of the site runs on <entity> Coldf...
# 47  The site was written using <entity> Macromedia...
# 48  It was dominated by the FreezeFry cycles of <e...
# 49  One region of the Neoproterozoic world which i...
